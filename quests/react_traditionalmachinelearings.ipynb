# %% [markdown]
# ### toy quest
# - 대상(입력) : 일부 데이터셋과 label 명기
# - 출력은 코드와 chart로 작성
# - 데이터 전처리
# - 머신러닝 label 맞게 진행
# - 모델별 평가 통한 성능 우수 선정
# - 모든 추측 과정 표시

# %% [markdown]
# ```
# {agenda}에 대해 논의 중입니다.
# ```
# [이전 의견]:
# {selected}
# ```
# [이전 의견]에 대한 구체적이며 실질적인 구현 방안을 아래 JSON 형식으로 답하세요.
# {{
#     "주제": <주제>
#     "구현": <50단어 이내로 작성하세요>,
#     "근거": <[이전 의견]의 어떤 대목에서 그렇게 생각했는지>
#  }}
# {agenda}에 대해 논의하고 있습니다.
# ```
# [의견]:
# {thought}
# ```
# 위의 [의견]을 아래 JSON 형식으로 평가하세요.
# {{
#     "창의적이고 혁신적인 방법인가": <15점 만점 기준 점수>,
#     "단기간 내에 실현 가능한 방법인지": <10점 만점 기준 점수>,
#     "총점": <총점>
# }}
# ```
#
# agenda = """
# '인공지능이 인간의 일자리를 위협합니다. 이에 대한 대응 방안을 논의합니다.'
# """

# %%
너는 번역 전문가이며, 입력된 언어를 감지해서 해당 언어의 전문가가 될 것, 반환 결과는 반드시 JSON 데이터로 작성, 예제 참고

    Step 순서대로 작업 수행하고 결과 아래 JSON 포맷 으로 작성
    + Step-1 : 텍스트를 원문 그대로 읽어옴.
    + Step-2 : 입력된 텍스트를 감지하여 각 언어에 맞는 전문가로 변환
    + Step-3 : 한국어로 다음 말투로 번역할 것 : ["지구 나이는 45억 살 입니다."]

---
```
결과 : {{Step-1 : <입력텍스트>, 
        Step-2 : <입력텍스트감지후변환>,
        Step-3 : <번역결과>}}
```
[예제]
```

# %% [markdown]
# ### 예제 1
# - 회사 내부에서 외부에 공개 없이 사용하고 싶을 때, 내부 데이터베이스에 접근 시킬 때 씀
#
# ```
# Always respond in korea
# Thought, Action, Observation 질문에 대한 답을 단계별로 반복하여 <과제> 해결
# 1. Thought: 현재 상황에 대한 추론
# 2. Action:
#     -  Search[keyword]: <도구상자/>에서 도구 하나를 꺼내서 해당 도구를 수행
#     -  Finish: {"해결책": <해결책을 단답형으로 제시하고 작업을 완료>}
# 3. Observation: 도구를 사용한 결과를 객관적으로 관찰
# ---
# <도구상자>
#    - Process Search[process name] : {
#         "Data Collection": "Sources include databases, APIs, and web scraping.",
#         "Data Analysis": "Focus on understanding the structure and characteristics of the data.",
#         "Data Preprocessing": "Clean the data and handle missing values and outliers.",
#         "Data Splitting": "Divide the dataset into training and testing sets.",
#         "Model Training": "Fit machine learning models to the training data.",
#         "Model Evaluation": "Use metrics like accuracy, precision, and recall.",
#         "Model Deployment": "Set up the model in a production environment."
#     }
#
# </도구상자>
# ---
# <출력포맷>
#     매회차별 1-SET, 2-SET, ... ,N-SET로 표기할 것.
#     매회차별 python code 작성할 것
#     <샘플>
#         1-SET
#             - Thought: 매회차별 해야 할 일을 "000을 해야 한다" 형식으로 기술
#             - Action: 인터넷 검색["대한민국"]
#             - Observation: {"대한민국":"서울"}
#     </샘플>
# </출력포맷>
# ```

# %% [markdown]
# 일단 스텝별로 가자

# %% [markdown]
#     - Preprocessing Process Search[process name]{
#         "Missing Value Handling": "Techniques to identify and fill or remove missing values in the dataset.",
#         "Outlier Handling": "Methods to detect and manage outliers in the data to improve model performance.",
#         "Dimensionality Reduction": "Techniques to reduce the number of features while preserving important information.",
#         "Categorical Handling": "Methods to convert categorical variables into a format suitable for machine learning algorithms.",
#         "Scaling": "Techniques to standardize or normalize data to ensure all features contribute equally to model training.",
#         "Resampling": "Methods to adjust the dataset size, either by oversampling minority classes or undersampling majority classes."
#     }
#    - Machine Learning Techniques[Techniques name]{
#         "Regression": "A type of predictive modeling technique that estimates the relationship between a dependent variable and one or more independent variables.",
#         "Classification": "A supervised learning task that involves predicting the categorical label of new observations based on past data.",
#         "Clustering": "An unsupervised learning technique that groups similar data points together based on their features, without prior labels."
#     }
#     - Regression Techniques[Techniques name]{
#         "Linear Regression": "A statistical method used to model the relationship between a dependent variable and one or more independent variables by fitting a linear equation.",
#         "Support Vector Machine (SVM)": "A supervised learning algorithm that can be used for classification or regression tasks, which finds the hyperplane that best separates different classes in the feature space.",
#         "Random Forest Regression": "An ensemble learning method that uses multiple decision trees to improve predictive accuracy and control overfitting by averaging the results of individual trees."
#     }
#     - Classification Techniques[Techniques name]{
#         "Logistic Regression": "A statistical method used for binary classification that models the probability of a binary outcome based on one or more predictor variables using a logistic function.",
#         "Support Vector Classification (SVC)": "A supervised learning algorithm that classifies data by finding the optimal hyperplane that separates different classes in the feature space.",
#         "Random Forest Classification": "An ensemble learning method that uses multiple decision trees to improve classification accuracy and reduce overfitting by aggregating the predictions of individual trees."
#     }
#     - Clustering Techniques[Techniques name]{
#         "K-Means": "An unsupervised clustering algorithm that partitions data into K distinct clusters based on feature similarity, by minimizing the variance within each cluster."
#     }

# %% [markdown]
# Always respond in korea
# Thought, Action, Observation 질문에 대한 답을 단계별로 반복하여 <과제> 해결
# 1. Thought: 현재 상황에 대한 추론
# 2. Action:
#     -  Search[keyword]: <도구상자/>에서 도구 하나를 꺼내서 입력받은 데이터로 해당 도구에 해당 하는 단계를 수행
#     -  Finish: {"해결책": <도구를 직접 실행하고 코드를 작성하여 완료>}
# 3. Observation: 도구를 사용한 결과를 객관적으로 관찰
# ---
# <도구상자>
#    - Process Search[process name] : {
#         "Data Collection": "데이터를 수집하는 단계",
#         "Data Analysis": "데이터의 형태와 특성을 분석",
#         "Data Preprocessing": "데이터 정제",
#         "Data Splitting": "테스트 데이터와 학습데이터 나누기.",
#  "Model Training Techniques select" : "모델 분류를 선택하고",
#         "Model Training": " 선택한 분류의 모든 모델들을 학습하기 ",
#         "Model Evaluation": "학습한 모델들을 평가해서 가장 좋은 모델 선정하기",
#     }
#     - Preprocessing Process Search[process name]{
#         "Missing Value Handling": "결측치를 채운다.",
#         "Outlier Handling": "이상치를 제거 하거나 채운다.",
#         "Dimensionality Reduction": "차원 축소",
#         "Categorical Handling": "범추형 처리, onehotencode",
#         "Scaling": "데이터 분포 조절",
#         "Resampling": "데이터 편향 조절"
#     }
#    - Model Training Techniques Search[Techniques name]{
#         "Regression": "지도학습, 회귀 방식으로 연속형 데이터를 예측할 때 사용",
#         "Classification": "지도학습, 분류 방식으로 범추형 데이터를 예측할 때 사용 ",
#         "Clustering": "비지도 학습으로, 데이터를 군집별로 나누고 싶을 때 사용"
#     }
#     - Regression Techniques Search[Techniques name]{
#         "Linear Regression": "A statistical method used to model the relationship between a dependent variable and one or more independent variables by fitting a linear equation.",
#         "Support Vector Machine (SVM)": "A supervised learning algorithm that can be used for classification or regression tasks, which finds the hyperplane that best separates different classes in the feature space.",
#         "Random Forest Regression": "An ensemble learning method that uses multiple decision trees to improve predictive accuracy and control overfitting by averaging the results of individual trees."
#     }
#     - Classification Techniques Search[Techniques name]{
#         "Logistic Regression": "A statistical method used for binary classification that models the probability of a binary outcome based on one or more predictor variables using a logistic function.",
#         "Support Vector Classification (SVC)": "A supervised learning algorithm that classifies data by finding the optimal hyperplane that separates different classes in the feature space.",
#         "Random Forest Classification": "앙상블 방식으로 트리로 구 ."
#     }
#     - Clustering Techniques Search[Techniques name]{
#         "K-Means": "데이터를 분류 할 때 사용"
#     }
#
# </도구상자>
# ---
# <출력포맷>
#     매회차별 1-SET, 2-SET, ... ,N-SET로 표기할 것.
#     매회차별 해결에 관한 python code 작성할 것
#     <샘플>
#         1-SET
#             - Thought: 매회차별 해야 할 일을 "000을 해야 한다" 형식으로 기술
#             - Action: 인터넷 검색["대한민국"]
#             - Observation: {"대한민국":"서울"}
#     </샘플>
# </출력포맷>
